# %%
import pandas as pd
import os

# Define paths to directories and files
old_data_dir = 'old_data'
new_data_file = 'data/clinic_genetic.csv'
new_data_file_out = 'data/clinic_genetic_formatted.csv'
extra_data_file_out = 'data/clinic_genetic_extra.csv'


from utils_fetch import start_date, end_date, query_terms_list, year_list, DATA_DIR

# %%
# Read all CSVs in the old data directory and concatenate
old_dataframes = []
for file in os.listdir(old_data_dir):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join(old_data_dir, file))
        old_dataframes.append(df)

# Concatenate all old dataframes, allowing for differing columns
old_data = pd.concat(old_dataframes, ignore_index=True)

old_data['title_form'] = old_data.title.apply(lambda x: str(x).lower().strip().strip('.').replace('\"', '').replace('\'', ''))

# Group by 'title' and 'abstract', keeping the first occurrence but detecting differing rows
grouped_old_data = old_data.groupby(['title_form',], as_index=False).first()
for _, group in old_data.groupby(['title_form',]):
    if len(group) > 1:
        differing_rows = group.loc[:, group.nunique() > 1]
        if not differing_rows.empty:
            print("Differing rows for title/abstract group:\n", differing_rows)
# Out:
# Differing rows for title/abstract group:
#                                                   title relevance
# 16   A Combined Manual Annotation and Deep-Learning...       2.0
# 256  A Combined Manual Annotation and Deep-Learning...         2
# Differing rows for title/abstract group:
#      relevance
# 219       2.0
# 257         2
# Differing rows for title/abstract group:
#      relevance
# 187       1.0
# 233         1
# Differing rows for title/abstract group:
#      relevance
# 191       1.0
# 234         1
# Differing rows for title/abstract group:
#      relevance
# 175       1.0
# 235         1
# Differing rows for title/abstract group:
#      relevance
# 9         2.0
# 258         2
# Differing rows for title/abstract group:
#      relevance
# 177       1.0
# 236         1
# Differing rows for title/abstract group:
#      relevance
# 10        2.0
# 259         2
# Differing rows for title/abstract group:
#      relevance                                           ai_topic
# 218       1.0                         ChatGPT; systematic review
# 252         1  ChatGPT; ML Task: Applications in bioinformati...
# Differing rows for title/abstract group:
#      relevance
# 210       2.0
# 260         2
# Differing rows for title/abstract group:
#      relevance
# 200       2.0
# 262         2
# Differing rows for title/abstract group:
#                                                   title  \
# 197  ChatGPT accurately performs genetic counseling...
# 263  ChatGPT accurately performs genetic counseling...
#
#                                               abstract relevance  \
# 197  Artificial Intelligence (AI) systems such as C...       2.0
# 263  Artificial Intelligence (AI) systems such as C...         2
#
#                                               ai_topic  \
# 197  ChatGPT-3.5; ML Task: Genetic counseling and a...
# 263  ChatGPT (v3.4, v3.5); ML Task: Answering genet...
#
#                                         medicine_topic  \
# 197  Genetic counseling for gynecologic cancers, in...
# 263  Genetic counseling for hereditary breast, ovar...
#
#                                                  notes
# 197  ChatGPT accurately answers 82.5% of genetic co...
# 263  ChatGPT answered 82.5% of questions correctly ...
# Differing rows for title/abstract group:
#      relevance
# 201       2.0
# 264         2
# Differing rows for title/abstract group:
#      relevance
# 215       1.0
# 253         1
# Differing rows for title/abstract group:
#      relevance                                           ai_topic  \
# 203       2.0  Transformer-based deep learning model (INTERAC...
# 265         2  Transformer-based deep learning model (Interac...
#
#                                         medicine_topic  \
# 203  Brain disorders (e.g., schizophrenia, depressi...
# 265   DNA methylation's role in schizophrenia, depr...
#
#                                                  notes
# 203  INTERACT predicts DNA methylation levels, enha...
# 265  Interact model achieved an AUC of 0.98, aiding...
# Differing rows for title/abstract group:
#      relevance
# 214       2.0
# 266         2
# Differing rows for title/abstract group:
#      relevance
# 15        2.0
# 267         2
# Differing rows for title/abstract group:
#      relevance
# 189       1.0
# 237         1
# Differing rows for title/abstract group:
#      relevance
# 8         2.0
# 268         2
# Differing rows for title/abstract group:
#      relevance
# 213       2.0
# 269         2
# Differing rows for title/abstract group:
#      relevance
# 204       2.0
# 270         2
# Differing rows for title/abstract group:
#      relevance
# 206       2.0
# 271         2
# Differing rows for title/abstract group:
#      relevance
# 17        2.0
# 272         2
# Differing rows for title/abstract group:
#      relevance
# 194       2.0
# 273         2
# Differing rows for title/abstract group:
#      relevance
# 14        2.0
# 274         2
# Differing rows for title/abstract group:
#      relevance
# 217       2.0
# 275         2
# Differing rows for title/abstract group:
#      relevance
# 199       2.0
# 276         2
# Differing rows for title/abstract group:
#      relevance
# 183       1.0
# 238         1
# Differing rows for title/abstract group:
#      relevance
# 180       1.0
# 239         1
# Differing rows for title/abstract group:
#      relevance
# 12        2.0
# 289         2
# Differing rows for title/abstract group:
#      relevance
# 13        2.0
# 277         2
# Differing rows for title/abstract group:
#      relevance
# 216       2.0
# 278         2
# Differing rows for title/abstract group:
#      relevance
# 181       1.0
# 227         1
# Differing rows for title/abstract group:
#      relevance
# 205       2.0
# 279         2
# Differing rows for title/abstract group:
#      relevance
# 196       2.0
# 280         2
# Differing rows for title/abstract group:
#      relevance
# 198       1.0
# 232         1
# Differing rows for title/abstract group:
#      relevance
# 179       1.0
# 240         1
# Differing rows for title/abstract group:
#      relevance
# 207       2.0
# 281         2
# Differing rows for title/abstract group:
#      relevance
# 208       2.0
# 282         2
# Differing rows for title/abstract group:
#      relevance
# 0         1.0
# 228         1
# Differing rows for title/abstract group:
#      relevance
# 176       1.0
# 241         1
# Differing rows for title/abstract group:
#      relevance
# 190       1.0
# 242         1
# Differing rows for title/abstract group:
#             relevance ai_topic not_relevant partly_relevant relevant from ST_1  \
# 18               NaN      NaN            1               7       10       NaN
# 221              NaN      NaN          154              25       23       NaN
# 290              NaN      NaN            0              33       35        48
# 291              NaN      NaN          NaN             NaN      NaN       NaN
# 292              NaN      NaN          NaN             NaN      NaN       NaN
# 293              NaN      NaN          NaN             NaN      NaN       NaN
# 294              NaN      NaN          NaN             NaN      NaN     equal
# 295        pre: KNLR      NaN          NaN             NaN      NaN         4
# 296          pre: RS     Disc          NaN             NaN      NaN         3
# 297         ana: AVE       36          NaN             NaN      NaN         9
# 298         ana: GVI      NaN          NaN             NaN      NaN         6
# 299         ana: MIA      NaN          NaN             NaN      NaN         6
# 300        post: PCS      NaN          NaN             NaN      NaN         2
# 301       post: DAPM      NaN          NaN             NaN      NaN         2
# 302      post: CRGDS      NaN          NaN             NaN      NaN         3
# 303              edu      NaN          NaN             NaN      NaN         3
# 304             disc      NaN          NaN             NaN      NaN         6
# 305  pre: KNLR, disc      NaN          NaN             NaN      NaN         1
# 306        edu, disc      NaN          NaN             NaN      NaN         1
# 307              NaN      NaN          NaN             NaN      NaN        46
#
#        used?
# 18       NaN
# 221      NaN
# 290       46
# 291      NaN
# 292      NaN
# 293      NaN
# 294  include
# 295        5
# 296        3
# 297        9
# 298        6
# 299        6
# 300        2
# 301        2
# 302        3
# 303        4
# 304        8
# 305        1
# 306        1
# 307       50
# Differing rows for title/abstract group:
#      relevance
# 185       1.0
# 243         1
# Differing rows for title/abstract group:
#      relevance
# 178       1.0
# 244         1
# Differing rows for title/abstract group:
#      relevance
# 220       2.0
# 283         2
# Differing rows for title/abstract group:
#      relevance
# 174       1.0
# 245         1
# Differing rows for title/abstract group:
#      relevance
# 195       2.0
# 284         2
# Differing rows for title/abstract group:
#      relevance
# 11        2.0
# 285         2
# Differing rows for title/abstract group:
#      relevance
# 192       1.0
# 229         1
# Differing rows for title/abstract group:
#      relevance
# 184       1.0
# 246         1
# Differing rows for title/abstract group:
#      relevance
# 211       1.0
# 254         1
# Differing rows for title/abstract group:
#      relevance
# 188       1.0
# 247         1
# Differing rows for title/abstract group:
#      relevance
# 202       2.0
# 286         2
# Differing rows for title/abstract group:
#      relevance
# 4         1.0
# 230         1
# Differing rows for title/abstract group:
#      relevance
# 212       2.0
# 287         2
# Differing rows for title/abstract group:
#      relevance
# 2         1.0
# 231         1
# Differing rows for title/abstract group:
#      relevance
# 182       1.0
# 248         1
# Differing rows for title/abstract group:
#      relevance
# 193       1.0
# 249         1
# Differing rows for title/abstract group:
#      relevance
# 209       2.0
# 288         2
# Differing rows for title/abstract group:
#      relevance
# 173       1.0
# 250         1
# Differing rows for title/abstract group:
#      relevance
# 186       1.0
# 251         1

# %%
grouped_old_data.title[1],grouped_old_data.title[2]
# Out:
# ('A Combined Manual Annotation and Deep-Learning Natural Language Processing Study on Accurate Entity Extraction in Hereditary Disease Related Biomedical Literature.',
#  'A comparative evaluation of ChatGPT 3.5 and ChatGPT 4 in responses to selected genetics questions')

# %%
cols_to_use = ['title', 'abstract', 'source', 'relevance', 'ai_topic',
       'medicine_topic', 'notes', 'used?', 'what section used', 'title_form']
grouped_old_data = grouped_old_data[cols_to_use]

print(grouped_old_data.shape)
grouped_old_data
# Out:
# (228, 10)
#                                                  title  \
# 0    A case of malignant pheochromocytoma with neur...
# 1    A Combined Manual Annotation and Deep-Learning...
# 2    A comparative evaluation of ChatGPT 3.5 and Ch...
# 3    A Comparative Sentiment Analysis of Greek Clin...
# 4    A complex mechanism translating variation of a...
# ..                                                 ...
# 223  Utilization of a Third-party Partnership in Te...
# 224  VarChat: the generative AI assistant for the i...
# 225  Virtual Labs and Designer Bugs - Generative AI...
# 226  Weakly Supervised Classification for Nasophary...
# 227  Whole-genome sequencing of half-a-million UK B...
#
#                                               abstract   source relevance  \
# 0    Neurofibromatosis type 1 is a hereditary condi...   PubMed       0.0
# 1    We report a combined manual annotation and dee...   PubMed       2.0
# 2    To evaluate the efficacy of ChatGPT 4 (GPT-4) ...   PubMed       2.0
# 3    In addressing the critical role of emotional c...   PubMed       1.0
# 4    Linking genes to traits is a central goal in b...  biorxiv       0.0
# ..                                                 ...      ...       ...
# 223  To meet the increasing demands of genetic risk...   PubMed       0.0
# 224  In the modern era of genomic research, the sci...   PubMed       2.0
# 225  AI technologies can pose a major national secu...   PubMed       1.0
# 226  Pathological examination of nasopharyngeal car...   PubMed       1.0
# 227  Summary ParagraphWhole-genome sequencing (WGS)...  medrxiv       0.0
#
#                                               ai_topic  \
# 0                                                 None
# 1    BERT-based and DistilBERT-based NER models; ML...
# 2    GPT-3.5, GPT-4; ML Task: Genetic information d...
# 3    BERT, RoBERTa, GPT-2, XLNet; ML Task: Sentimen...
# 4                                                 None
# ..                                                 ...
# 223                                               None
# 224  Generative AI; ML Task: Literature search and ...
# 225  No specific transformer-based models like GPT ...
# 226  Vision Transformer (T2T-ViT); ML Task: Image c...
# 227                                               None
#
#                                         medicine_topic  \
# 0                                                 None
# 1    Entity extraction in hereditary disease-relate...
# 2    Genetic conditions (BRCA1, HFE, MLH1) and gene...
# 3    Sentiment analysis of patient-clinician conver...
# 4                                                 None
# ..                                                 ...
# 223                                               None
# 224  Interpretation of genomic variants using summa...
# 225  Genetic research with a focus on synthetic bio...
# 226   Cancer diagnosis using whole slide images (WS...
# 227                                               None
#
#                                                  notes used?  \
# 0                                                 None  None
# 1    BERT-based NER achieved high F1-scores for gen...     1
# 2    GPT-4 performs better than GPT-3.5 in genetic ...     1
# 3    Importance of different language incorporation...  None
# 4                                                 None  None
# ..                                                 ...   ...
# 223                                               None  None
# 224  VarChat summarizes genomic variant data from s...     1
# 225  AI's role in genetic research and biological s...  None
# 226  Proposes a weakly supervised transformer frame...  None
# 227                                               None  None
#
#     what section used                                         title_form
# 0                None  a case of malignant pheochromocytoma with neur...
# 1     pre: KNLR, disc  a combined manual annotation and deep-learning...
# 2           edu, disc  a comparative evaluation of chatgpt 3.5 and ch...
# 3                None  a comparative sentiment analysis of greek clin...
# 4                None  a complex mechanism translating variation of a...
# ..                ...                                                ...
# 223              None  utilization of a third-party partnership in te...
# 224          ana: GVI  varchat: the generative ai assistant for the i...
# 225              None  virtual labs and designer bugs - generative ai...
# 226              None  weakly supervised classification for nasophary...
# 227              None  whole-genome sequencing of half-a-million uk b...
#
# [228 rows x 10 columns]

# %%
# Read the new data
new_data = pd.read_csv(new_data_file)
new_data['title_form'] = new_data.title.apply(lambda x: str(x).lower().strip().strip('.').replace('\"', '').replace('\'', ''))
print(new_data.shape)

# Add missing columns from old data to new data
for col in grouped_old_data.columns:
    if col not in new_data.columns:
        new_data[col] = None

# Update values in new data with old data where title and abstract match
merged_data = new_data.merge(
    grouped_old_data, on=['title_form'], how='left', suffixes=('', '_old')
)
for col in grouped_old_data.columns:
    if col not in ['title', 'title_form']:
        merged_data[col] = merged_data[col].combine_first(merged_data[col + '_old'])

# Add a new column to indicate existence in old data
merged_data['existed_in_old_data'] = merged_data['title'].isin(grouped_old_data['title'])
merged_data = merged_data[['title', 'abstract', 'source', 'title_form', 'relevance', 'ai_topic',
       'medicine_topic', 'notes', 'used?', 'what section used', 'existed_in_old_data']]

# Create an extra dataframe with rows not in the new data based on 'title' and 'abstract'
extra_data = grouped_old_data[
    ~grouped_old_data.set_index(['title']).index.isin(
        new_data.set_index(['title']).index
    )
]
# Out:
# (576, 4)

# %%
merged_data.to_csv(new_data_file_out, index=False, sep=',')
print(f"Prev anno: {sum(merged_data.existed_in_old_data)}")
merged_data
# Out:
# Prev anno: 95
#                                                  title  \
# 0    Natural Language Processing and Schizophrenia:...
# 1    Harnessing generative AI to annotate the sever...
# 2    Leveraging hierarchical structures for genetic...
# 3    16S rRNA gene sequencing for bacterial identif...
# 4    A Systematic Review of Testing and Evaluation ...
# ..                                                 ...
# 571  A self-supervised framework for learning whole...
# 572  Machine learning-based donor permission extrac...
# 573  Accuracy of generative artificial intelligence...
# 574  Enhancing human phenotype ontology term extrac...
# 575  A recently collected Xanthomonas translucens i...
#
#                                               abstract          source  \
# 0    (1) Background: Approximately 1% of the global...          PubMed
# 1    0.1There are thousands of human phenotypes whi...         medrxiv
# 2    1.Initially introduced in 1909 by William Bate...  PubMed,medrxiv
# 3    16S rRNA gene sequence is the most common hous...         biorxiv
# 4    1ImportanceLarge Language Models (LLMs) can as...         medrxiv
# ..                                                 ...             ...
# 571  Whole slide imaging is fundamental to biomedic...           arXiv
# 572  With more clinical trials are offering optiona...          PubMed
# 573  With the increasing development of artificial ...          PubMed
# 574  With the increasing utilization of exome and g...          PubMed
# 575  Xanthomonas translucens, the causal agent of b...         biorxiv
#
#                                             title_form relevance  \
# 0    natural language processing and schizophrenia:...       NaN
# 1    harnessing generative ai to annotate the sever...       NaN
# 2    leveraging hierarchical structures for genetic...       NaN
# 3    16s rrna gene sequencing for bacterial identif...       NaN
# 4    a systematic review of testing and evaluation ...       1.0
# ..                                                 ...       ...
# 571  a self-supervised framework for learning whole...       NaN
# 572  machine learning-based donor permission extrac...       NaN
# 573  accuracy of generative artificial intelligence...       NaN
# 574  enhancing human phenotype ontology term extrac...       NaN
# 575  a recently collected xanthomonas translucens i...       0.0
#
#                                               ai_topic  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Various Large Language Models (LLMs) like GPT ...
# ..                                                 ...
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 574                                                NaN
# 575                                               None
#
#                                         medicine_topic  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Healthcare applications, especially in clinica...
# ..                                                 ...
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 574                                                NaN
# 575                                               None
#
#                                                  notes used?  \
# 0                                                  NaN   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4    Evaluates LLMs in healthcare for diverse tasks...  None
# ..                                                 ...   ...
# 571                                                NaN   NaN
# 572                                                NaN   NaN
# 573                                                NaN   NaN
# 574                                                NaN   NaN
# 575                                               None  None
#
#     what section used  existed_in_old_data
# 0                 NaN                False
# 1                 NaN                False
# 2                 NaN                False
# 3                 NaN                False
# 4                None                 True
# ..                ...                  ...
# 571               NaN                False
# 572               NaN                False
# 573               NaN                False
# 574               NaN                False
# 575              None                 True
#
# [576 rows x 11 columns]

# %%
extra_data.to_csv(extra_data_file_out, index=False, sep=',')
print(f"Prev anno, not_used: {extra_data.shape}")
extra_data
# Out:
# Prev anno, not_used: (133, 10)
#                                                  title  \
# 0    A case of malignant pheochromocytoma with neur...
# 1    A Combined Manual Annotation and Deep-Learning...
# 3    A Comparative Sentiment Analysis of Greek Clin...
# 5    A foundational large language model for edible...
# 6    A Metabolic Biomarker Panel for Congenital Hea...
# ..                                                 ...
# 216  Unraveling the Enigma of Aortic Dissection: Fr...
# 217  UnSegGNet: Unsupervised Image Segmentation usi...
# 219  Unveiling the Link Between Celiac Disease and ...
# 221  Using Large Language Models to Annotate Comple...
# 223  Utilization of a Third-party Partnership in Te...
#
#                                               abstract          source  \
# 0    Neurofibromatosis type 1 is a hereditary condi...          PubMed
# 1    We report a combined manual annotation and dee...          PubMed
# 3    In addressing the critical role of emotional c...          PubMed
# 5    Significant progress has been made in the fiel...  PubMed,biorxiv
# 6    BackgroundCongenital heart disease (CHD) repre...         medrxiv
# ..                                                 ...             ...
# 216  Aortic dissection (AD) presents a critical med...          PubMed
# 217  Image segmentation, the process of partitionin...           arXiv
# 219  Celiac disease (CD) is a systemic autoimmune d...          PubMed
# 221  Social Determinants of Health (SDoH) are an im...          PubMed
# 223  To meet the increasing demands of genetic risk...          PubMed
#
#     relevance                                           ai_topic  \
# 0         0.0                                               None
# 1         2.0  BERT-based and DistilBERT-based NER models; ML...
# 3         1.0  BERT, RoBERTa, GPT-2, XLNet; ML Task: Sentimen...
# 5         1.0  Large language model (AgroNT); ML Task: Genomi...
# 6         0.0                                               None
# ..        ...                                                ...
# 216       0.0                                               None
# 217       1.0  Graph Neural Networks (GNN), Vision Transforme...
# 219       0.0                                               None
# 221       0.0  GPT-3.5, GPT-4; ML Task: Annotating social det...
# 223       0.0                                               None
#
#                                         medicine_topic  \
# 0                                                 None
# 1    Entity extraction in hereditary disease-relate...
# 3    Sentiment analysis of patient-clinician conver...
# 5    Genomic prediction for plant species using DNA...
# 6                                                 None
# ..                                                 ...
# 216                                               None
# 217  Unsupervised medical image segmentation using ...
# 219                                               None
# 221   SDOH identification (housing instability) fro...
# 223                                               None
#
#                                                  notes used?  \
# 0                                                 None  None
# 1    BERT-based NER achieved high F1-scores for gen...     1
# 3    Importance of different language incorporation...  None
# 5    AgroNT predicts regulatory annotations and fun...  None
# 6                                                 None  None
# ..                                                 ...   ...
# 216                                               None  None
# 217  GNN-based unsupervised segmentation performs w...     1
# 219                                               None  None
# 221  GPT-4 outperformed manual annotation and NER m...  None
# 223                                               None  None
#
#     what section used                                         title_form
# 0                None  a case of malignant pheochromocytoma with neur...
# 1     pre: KNLR, disc  a combined manual annotation and deep-learning...
# 3                None  a comparative sentiment analysis of greek clin...
# 5                None  a foundational large language model for edible...
# 6                None  a metabolic biomarker panel for congenital hea...
# ..                ...                                                ...
# 216              None  unraveling the enigma of aortic dissection: fr...
# 217          ana: MIA  unseggnet: unsupervised image segmentation usi...
# 219              None  unveiling the link between celiac disease and ...
# 221              None  using large language models to annotate comple...
# 223              None  utilization of a third-party partnership in te...
#
# [133 rows x 10 columns]

# %%
len(set(merged_data.title))
# Out:
# 576

# %% [markdown]
# ## CHECK

# %%
import pandas as pd
from collections import Counter

# %%
# generated_df = pd.read_csv(os.path.join(DATA_DIR, "clinic_genetic.csv"))
# init_df = pd.read_csv('/home/toharhymes/Downloads/clinic_genetic_formatted - raw_clinic_genetic_formatted.csv')
shortened_df = pd.read_csv('/home/toharhymes/Downloads/clinic_genetic_formatted - raw_ST1.csv')
upd_df = pd.read_csv('/home/toharhymes/Downloads/clinic_genetic_formatted - ST1_with_added_(ST2).csv')

print(shortened_df.shape, upd_df.shape)
print(len(set(shortened_df.title)), len(set(upd_df.title)))
# Out:
# (551, 16) (307, 22)
# 551 307

# %%
r_shortened_df = shortened_df[shortened_df.relevance=='2']

# %%
len(upd_df.title),len(r_shortened_df.title)
# Out:
# (307, 165)

# %%
len(set(upd_df.title)),len(set(r_shortened_df.title))
# Out:
# (307, 165)

# %%
len(set(upd_df.title.apply(lambda x: x.lower()))),len(set(r_shortened_df.title.apply(lambda x: x.lower())))
# Out:
# (307, 165)

# %%
set(upd_df.title)-set(shortened_df.title)
# Out:
# {'Accurate proteome-wide missense variant effect prediction with AlphaMissense',
#  'DUVEL: an active-learning annotated biomedical corpus for the recognition of oligogenic combinations',
#  'GENA-LM: A Family of Open-Source Foundational',
#  'GeneGPT: augmenting large language models with domain tools for improved access to biomedical information',
#  'Identifying facial phenotypes of genetic disorders using deep learning'}

# %%
len(set(shortened_df.title) & set(init_df.title))
# Out:
# 552

# %%
set(shortened_df.title) - set(init_df.title)
# Out:
# {'Genetic and phenotypic analysis of the virulence plasmid of a non-Shigatoxigenic enteroaggregative ',
#  'Multi-view graph learning for deciphering the dominant cell communication assembly of downstream functional events from single-cell RNA-seq data ======================== scDCA: deciphering the dominant cell communication assembly of downstream functional events from single-cell RNA-seq data'}

# %%
set(init_df.title) - set(shortened_df.title)
# Out:
# {'Assessing the utility of large language models for phenotype-driven gene prioritization in the diagnosis of rare genetic disease',
#  'Empowering Personalized Pharmacogenomics with Generative AI Solutions',
#  'Enhancing phenotype recognition in clinical notes using large language models: PhenoBCBERT and PhenoGPT',
#  'Enhancing recognition and interpretation of functional phenotypic sequences through fine-tuning pre-trained genomic models',
#  'Evaluating GPT and BERT models for protein-protein interaction identification in biomedical text',
#  "Feasibility of Identifying Factors Related to Alzheimer's Disease and Related Dementia in Real-World Data",
#  'Generating 3D brain tumor regions in MRI using vector-quantization Generative Adversarial Networks',
#  'Genetic and phenotypic analysis of the virulence plasmid of a non-Shigatoxigenic enteroaggregative \tEscherichia coli O104:H4 outbreak strain',
#  'Identification of parthenogenesis-inducing effector proteins in Wolbachia',
#  'Multi-view graph learning for deciphering the dominant cell communication assembly of downstream functional events from single-cell RNA-seq data',
#  'Multimodal data fusion using sparse canonical correlation analysis and cooperative learning: a COVID-19 cohort study',
#  'Precision phenotyping for curating research cohorts of patients with unexplained post-acute sequelae of COVID-19',
#  'PubTator 3.0: an AI-powered literature resource for unlocking biomedical knowledge',
#  'The clinical and genetic spectrum of paediatric speech and language disorders',
#  'Unmasking and quantifying racial bias of large language models in medical report generation',
#  "Unpacking Unstructured Data: A Pilot Study on Extracting Insights from Neuropathological Reports of Parkinson's Disease Patients using Large Language Models",
#  'hART: Deep learning-informed lifespan heart failure risk trajectories',
#  'nanoBERT: a deep learning model for gene agnostic navigation of the nanobody mutational space',
#  'scDCA: deciphering the dominant cell communication assembly of downstream functional events from single-cell RNA-seq data'}
