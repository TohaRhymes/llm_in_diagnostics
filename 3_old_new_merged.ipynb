# %%
import pandas as pd
import os

# Define paths to directories and files
old_data_dir = 'old_data'
new_data_file = 'data/clinic_genetic.csv'
new_data_file_out = 'data/clinic_genetic_formatted.csv'
extra_out = 'data/clinic_genetic_extra.csv'

# %%
# Read all CSVs in the old data directory and concatenate
old_dataframes = []
for file in os.listdir(old_data_dir):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join(old_data_dir, file))
        old_dataframes.append(df)

# Concatenate all old dataframes, allowing for differing columns
old_data = pd.concat(old_dataframes, ignore_index=True)

# Group by 'title' and 'abstract', keeping the first occurrence but detecting differing rows
grouped_old_data = old_data.groupby(['title',], as_index=False).first()
for _, group in old_data.groupby(['title',]):
    if len(group) > 1:
        differing_rows = group.loc[:, group.nunique() > 1]
        if not differing_rows.empty:
            print("Differing rows for title/abstract group:\n", differing_rows)
# Out:
# Differing rows for title/abstract group:
#      relevance
# 191       1.0
# 234         1
# Differing rows for title/abstract group:
#      relevance
# 175       1.0
# 235         1
# Differing rows for title/abstract group:
#      relevance
# 219       2.0
# 257         2
# Differing rows for title/abstract group:
#      relevance
# 187       1.0
# 233         1
# Differing rows for title/abstract group:
#      relevance
# 9         2.0
# 258         2
# Differing rows for title/abstract group:
#      relevance
# 177       1.0
# 236         1
# Differing rows for title/abstract group:
#      relevance
# 10        2.0
# 259         2
# Differing rows for title/abstract group:
#      relevance
# 210       2.0
# 260         2
# Differing rows for title/abstract group:
#      relevance                                           ai_topic
# 218       1.0                         ChatGPT; systematic review
# 252         1  ChatGPT; ML Task: Applications in bioinformati...
# Differing rows for title/abstract group:
#      relevance
# 201       2.0
# 264         2
# Differing rows for title/abstract group:
#      relevance
# 200       2.0
# 262         2
# Differing rows for title/abstract group:
#      relevance
# 215       1.0
# 253         1
# Differing rows for title/abstract group:
#      relevance
# 8         2.0
# 268         2
# Differing rows for title/abstract group:
#      relevance                                           ai_topic  \
# 203       2.0  Transformer-based deep learning model (INTERAC...
# 265         2  Transformer-based deep learning model (Interac...
#
#                                         medicine_topic  \
# 203  Brain disorders (e.g., schizophrenia, depressi...
# 265   DNA methylation's role in schizophrenia, depr...
#
#                                                  notes
# 203  INTERACT predicts DNA methylation levels, enha...
# 265  Interact model achieved an AUC of 0.98, aiding...
# Differing rows for title/abstract group:
#      relevance
# 214       2.0
# 266         2
# Differing rows for title/abstract group:
#      relevance
# 15        2.0
# 267         2
# Differing rows for title/abstract group:
#      relevance
# 189       1.0
# 237         1
# Differing rows for title/abstract group:
#      relevance
# 213       2.0
# 269         2
# Differing rows for title/abstract group:
#      relevance
# 204       2.0
# 270         2
# Differing rows for title/abstract group:
#      relevance
# 206       2.0
# 271         2
# Differing rows for title/abstract group:
#      relevance
# 17        2.0
# 272         2
# Differing rows for title/abstract group:
#      relevance
# 194       2.0
# 273         2
# Differing rows for title/abstract group:
#      relevance
# 14        2.0
# 274         2
# Differing rows for title/abstract group:
#      relevance
# 13        2.0
# 277         2
# Differing rows for title/abstract group:
#      relevance
# 217       2.0
# 275         2
# Differing rows for title/abstract group:
#      relevance
# 199       2.0
# 276         2
# Differing rows for title/abstract group:
#      relevance
# 180       1.0
# 239         1
# Differing rows for title/abstract group:
#      relevance
# 12        2.0
# 289         2
# Differing rows for title/abstract group:
#      relevance
# 183       1.0
# 238         1
# Differing rows for title/abstract group:
#      relevance
# 216       2.0
# 278         2
# Differing rows for title/abstract group:
#      relevance
# 181       1.0
# 227         1
# Differing rows for title/abstract group:
#      relevance
# 205       2.0
# 279         2
# Differing rows for title/abstract group:
#      relevance
# 196       2.0
# 280         2
# Differing rows for title/abstract group:
#      relevance
# 198       1.0
# 232         1
# Differing rows for title/abstract group:
#      relevance
# 179       1.0
# 240         1
# Differing rows for title/abstract group:
#      relevance
# 207       2.0
# 281         2
# Differing rows for title/abstract group:
#      relevance
# 208       2.0
# 282         2
# Differing rows for title/abstract group:
#      relevance
# 0         1.0
# 228         1
# Differing rows for title/abstract group:
#      relevance
# 176       1.0
# 241         1
# Differing rows for title/abstract group:
#      relevance
# 190       1.0
# 242         1
# Differing rows for title/abstract group:
#      relevance
# 185       1.0
# 243         1
# Differing rows for title/abstract group:
#      relevance
# 178       1.0
# 244         1
# Differing rows for title/abstract group:
#      relevance
# 220       2.0
# 283         2
# Differing rows for title/abstract group:
#      relevance
# 195       2.0
# 284         2
# Differing rows for title/abstract group:
#      relevance
# 174       1.0
# 245         1
# Differing rows for title/abstract group:
#      relevance
# 11        2.0
# 285         2
# Differing rows for title/abstract group:
#      relevance
# 192       1.0
# 229         1
# Differing rows for title/abstract group:
#      relevance
# 184       1.0
# 246         1
# Differing rows for title/abstract group:
#      relevance
# 211       1.0
# 254         1
# Differing rows for title/abstract group:
#      relevance
# 188       1.0
# 247         1
# Differing rows for title/abstract group:
#      relevance
# 202       2.0
# 286         2
# Differing rows for title/abstract group:
#      relevance
# 4         1.0
# 230         1
# Differing rows for title/abstract group:
#      relevance
# 2         1.0
# 231         1
# Differing rows for title/abstract group:
#      relevance
# 212       2.0
# 287         2
# Differing rows for title/abstract group:
#      relevance
# 182       1.0
# 248         1
# Differing rows for title/abstract group:
#      relevance
# 193       1.0
# 249         1
# Differing rows for title/abstract group:
#      relevance
# 209       2.0
# 288         2
# Differing rows for title/abstract group:
#      relevance
# 173       1.0
# 250         1
# Differing rows for title/abstract group:
#      relevance
# 186       1.0
# 251         1

# %%
cols_to_use = ['title', 'abstract', 'source', 'relevance', 'ai_topic',
       'medicine_topic', 'notes', 'used?', 'what section used']
grouped_old_data = grouped_old_data[cols_to_use]

print(grouped_old_data.shape)
grouped_old_data
# Out:
# (229, 9)
#                                                  title  \
# 0    "Having cancer is very expensive": A qualitati...
# 1    A Combined Manual Annotation and Deep-Learning...
# 2    A Combined Manual Annotation and Deep-Learning...
# 3    A Comparative Sentiment Analysis of Greek Clin...
# 4    A Metabolic Biomarker Panel for Congenital Hea...
# ..                                                 ...
# 224  Utilization of a Third-party Partnership in Te...
# 225  VarChat: the generative AI assistant for the i...
# 226  Virtual Labs and Designer Bugs - Generative AI...
# 227  Weakly Supervised Classification for Nasophary...
# 228  Whole-genome sequencing of half-a-million UK B...
#
#                                               abstract   source relevance  \
# 0    To examine patient barriers and facilitators t...   PubMed       0.0
# 1    We report a combined manual annotation and dee...   PubMed         2
# 2    We report a combined manual annotation and dee...   PubMed       2.0
# 3    In addressing the critical role of emotional c...   PubMed       1.0
# 4    BackgroundCongenital heart disease (CHD) repre...  medrxiv       0.0
# ..                                                 ...      ...       ...
# 224  To meet the increasing demands of genetic risk...   PubMed       0.0
# 225  In the modern era of genomic research, the sci...   PubMed       2.0
# 226  AI technologies can pose a major national secu...   PubMed       1.0
# 227  Pathological examination of nasopharyngeal car...   PubMed       1.0
# 228  Summary ParagraphWhole-genome sequencing (WGS)...  medrxiv       0.0
#
#                                               ai_topic  \
# 0                                                 None
# 1    BERT-based and DistilBERT-based NER models; ML...
# 2    BERT-based and DistilBERT-based NER models; ML...
# 3    BERT, RoBERTa, GPT-2, XLNet; ML Task: Sentimen...
# 4                                                 None
# ..                                                 ...
# 224                                               None
# 225  Generative AI; ML Task: Literature search and ...
# 226  No specific transformer-based models like GPT ...
# 227  Vision Transformer (T2T-ViT); ML Task: Image c...
# 228                                               None
#
#                                         medicine_topic  \
# 0                                                 None
# 1    Entity extraction in hereditary disease-relate...
# 2    Entity extraction in hereditary disease-relate...
# 3    Sentiment analysis of patient-clinician conver...
# 4                                                 None
# ..                                                 ...
# 224                                               None
# 225  Interpretation of genomic variants using summa...
# 226  Genetic research with a focus on synthetic bio...
# 227   Cancer diagnosis using whole slide images (WS...
# 228                                               None
#
#                                                  notes used? what section used
# 0                                                 None  None              None
# 1    BERT-based NER achieved high F1-scores for gen...     1   pre: KNLR, disc
# 2    BERT-based NER achieved high F1-scores for gen...  None              None
# 3    Importance of different language incorporation...  None              None
# 4                                                 None  None              None
# ..                                                 ...   ...               ...
# 224                                               None  None              None
# 225  VarChat summarizes genomic variant data from s...     1          ana: GVI
# 226  AI's role in genetic research and biological s...  None              None
# 227  Proposes a weakly supervised transformer frame...  None              None
# 228                                               None  None              None
#
# [229 rows x 9 columns]

# %%
# Read the new data
new_data = pd.read_csv(new_data_file)
print(new_data.shape)

# Add missing columns from old data to new data
for col in grouped_old_data.columns:
    if col not in new_data.columns:
        new_data[col] = None

# Update values in new data with old data where title and abstract match
merged_data = new_data.merge(
    grouped_old_data, on=['title'], how='left', suffixes=('', '_old')
)
for col in grouped_old_data.columns:
    if col not in ['title']:
        merged_data[col] = merged_data[col].combine_first(merged_data[col + '_old'])

# Add a new column to indicate existence in old data
merged_data['existed_in_old_data'] = merged_data['title'].isin(grouped_old_data['title']) 

# Create an extra dataframe with rows not in the new data based on 'title' and 'abstract'
extra_data = grouped_old_data[
    ~grouped_old_data.set_index(['title']).index.isin(
        new_data.set_index(['title']).index
    )
]
# Out:
# (1830, 3)

# %%
merged_data.to_csv(new_data_file_out, index=False, sep=',')
print(f"Prev anno: {sum(merged_data.existed_in_old_data)}")
merged_data
# Out:
# Prev anno: 193
#                                                   title  \
# 0     Dynamic Evolution of SARS-CoV-2 in West Sumatr...
# 1     Natural Language Processing and Schizophrenia:...
# 2     MIRACUM-Pipe: An Adaptable Pipeline for Next-G...
# 3     Diagnostic Challenges in ABCA4-Associated Reti...
# 4     Harnessing generative AI to annotate the sever...
# ...                                                 ...
# 1825                  Zellweger Syndrome: A Case Report
# 1826  The clinical impact of mRNA therapeutics in th...
# 1827  Contribution of Genetic Test to Early Diagnosi...
# 1828  Team Approach: Diagnosis, Management, and Prev...
# 1829  AN INCREASED RISK OF HORMONAL DISORDERS, PRIMA...
#
#                                                abstract   source relevance  \
# 0     &lt;b&gt;Background and Objective:&lt;/b&gt; T...   PubMed       NaN
# 1     (1) Background: Approximately 1% of the global...   PubMed       NaN
# 2     (1) Background: Next-generation sequencing (NG...   PubMed       NaN
# 3     (1) Purpose: ABCA4-associated retinal degenera...   PubMed       NaN
# 4     0.1There are thousands of human phenotypes whi...  medrxiv       NaN
# ...                                                 ...      ...       ...
# 1825  Zellweger syndrome is an autosomal recessive d...   PubMed       NaN
# 1826  mRNA-based therapeutics have revolutionized me...   PubMed       NaN
# 1827  the deficiency of 5,10-Methylenetetrahydrofola...   PubMed       NaN
# 1828  » Sudden cardiac events during sports competit...   PubMed       NaN
# 1829  β-Thalassemia major is an inherited blood cond...   PubMed       NaN
#
#      ai_topic medicine_topic notes used? what section used abstract_old  \
# 0         NaN            NaN   NaN   NaN               NaN          NaN
# 1         NaN            NaN   NaN   NaN               NaN          NaN
# 2         NaN            NaN   NaN   NaN               NaN          NaN
# 3         NaN            NaN   NaN   NaN               NaN          NaN
# 4         NaN            NaN   NaN   NaN               NaN          NaN
# ...       ...            ...   ...   ...               ...          ...
# 1825      NaN            NaN   NaN   NaN               NaN          NaN
# 1826      NaN            NaN   NaN   NaN               NaN          NaN
# 1827      NaN            NaN   NaN   NaN               NaN          NaN
# 1828      NaN            NaN   NaN   NaN               NaN          NaN
# 1829      NaN            NaN   NaN   NaN               NaN          NaN
#
#      source_old relevance_old ai_topic_old medicine_topic_old notes_old  \
# 0           NaN           NaN          NaN                NaN       NaN
# 1           NaN           NaN          NaN                NaN       NaN
# 2           NaN           NaN          NaN                NaN       NaN
# 3           NaN           NaN          NaN                NaN       NaN
# 4           NaN           NaN          NaN                NaN       NaN
# ...         ...           ...          ...                ...       ...
# 1825        NaN           NaN          NaN                NaN       NaN
# 1826        NaN           NaN          NaN                NaN       NaN
# 1827        NaN           NaN          NaN                NaN       NaN
# 1828        NaN           NaN          NaN                NaN       NaN
# 1829        NaN           NaN          NaN                NaN       NaN
#
#      used?_old what section used_old  existed_in_old_data
# 0          NaN                   NaN                False
# 1          NaN                   NaN                False
# 2          NaN                   NaN                False
# 3          NaN                   NaN                False
# 4          NaN                   NaN                False
# ...        ...                   ...                  ...
# 1825       NaN                   NaN                False
# 1826       NaN                   NaN                False
# 1827       NaN                   NaN                False
# 1828       NaN                   NaN                False
# 1829       NaN                   NaN                False
#
# [1830 rows x 18 columns]

# %%
merged_data.to_csv(new_data_file_out, index=False, sep=',')
print(f"Prev anno, not_ised: {sum(merged_data.existed_in_old_data)}")
merged_data
# Out:
# (36, 9)
